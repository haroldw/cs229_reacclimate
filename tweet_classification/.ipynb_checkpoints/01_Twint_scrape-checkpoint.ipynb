# %% [markdown]
# Documentation: https://pypi.org/project/twint/

# %%
import pandas as pd
import numpy as np
import csv
from collections import Counter

# %%
# Read in 100 users per side
influential_csv = pd.read_csv('influential_tweeters.csv')

# %%
influential_csv.head(50)
# Out:
#           affirming          denying
# 0            algore   skepticscience
# 1           oxfamgb  ScienceNotDogma
# 2     globalactplan       Carbongate
# 3      GreenpeaceUK        Neets2245
# 4       WWF_Climate         Co2Green
# 5        OneClimate       thegwpfcom
# 6       Ed_Miliband     CO2Coalition
# 7     CarolineLucas     Action4Life_
# 8         DECCgovuk   fredpalmercoal
# 9     the_ecologist     NoTricksZone
# 10         James_BG       FChecker76
# 11           Revkin   caleb_rossiter
# 12      ClimateDesk  FriendsofCoalWV
# 13  climateprogress      JunkScience
# 14            grist         CO2notes
# 15       TreeHugger   ClimateSkeptic
# 16    kate_sheppard        eloarefab
# 17            drvox        adapt2030
# 18       bradplumer           JWSpry
# 19      simondonner          pplonia
# 20       ayanaeliza          ILuvCO2
# 21       MaryHeglar       uk_ecology
# 22      maanvisings     IceAgeFarmer
# 23      ABarnardNYT    msroberts0619
# 24   earthinstitute  wattsupwiththat
# 25        lisalsong   ThiagoMaia2503
# 26    dwallacewells  realDonaldTrump
# 27    GretaThunberg        ccdeditor
# 28           kzhill     ClimateDepot
# 29       J_M_Fitton  Electroversenet
# 30         YaleE360  FriendsOScience
# 31      guardianeco    ClimatismBlog
# 32    Amelia_Womack  ClimateRealists
# 33      ClimateHome     Tony__Heller
# 34    KarlMathiesen     ChrisMartzWX
# 35      PaulEDawson        IceAgeBob
# 36          floodsg          UvMeter
# 37          Khayhoe    GrandSolarMin
# 38     TimesClimate   KnowYourGreen1
# 39   DrShepherd2013      seanhannity
# 40     EstherNgumbi       Timbooooon
# 41      climategeek       StarryPole
# 42     coralsncaves          co2_the
# 43      NaomiAKlein      grand_solar
# 44    JustinHGillis    ClimateHiJinx
# 45      SasjaBeslik   caleb_rossiter
# 46       PEspinosaC  SylviaD32911201
# 47       MikeHudema       ScubaHobbs
# 48      LeoDiCaprio          notGHGs
# 49         tveitdal  clim8resistance

# %%
influential_csv.shape
# Out:
# (99, 2)

# %%
print(len(np.unique(influential_csv['denying'])))
print(len(np.unique(influential_csv['affirming'])))
# Out:
# 96
# 96

# %%
print(len(influential_csv['denying']))
print(len(influential_csv['affirming']))
# Out:
# 99
# 99

# %%
[x for x in Counter(influential_csv['denying']) if Counter(influential_csv['denying'])[x] > 1]
# Out:
# []

# %%
[x for x in Counter(influential_csv['affirming']) if Counter(influential_csv['affirming'])[x] > 1]
# Out:
# []

# %%
influential_csv['denying'].drop_duplicates(keep='first',inplace=True)
influential_csv['affirming'].drop_duplicates(keep='first',inplace=True)

# %%
influential_csv.shape
# Out:
# (99, 2)

# %% [markdown]
# Scrape these users' tweets using Twint:

# %%
import twint
import nest_asyncio
import os
nest_asyncio.apply()

# %%
SEARCH_TERMS = ["sea","ice","melt","co2","methane","greenhouse","carbon",
               "emission","anthropogenic","temperature","warming","climate","coal","IPCC","environment",
               "environmental","cap and trade",'energy','planet','renewable','fossil fuel','environmentalist']
# TO DO: expand search_terms w/ some of Zach's terms

# %%
SCRAPE_DIR = '/per_user_search_term_scrapes'

# %%
def create_twint_config(user,end_date,search_term):
    c = twint.Config()
    c.Show_hashtags = True
    c.Count = True
    c.Stats = True
    c.Store_csv = True
    c.Retweets = False
    c.Custom["tweet"] = ["id", "date", "time", "tweet", "mentions", "replies_count", "retweets_count", 
                         "likes_count", "hashtags", "username"]
    c.Format = "ID {id} -||- Date {date} -||- Time {time} -||- Tweet {tweet} -||- Mentions {mentions} -||- \
    Repliescount {replies_count} \
    -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags {hashtags} -||- Username {username}"
    sep = " -||- "
    c.Username = user
    c.Until = end_date
    c.Search = search_term
    
    return c

# %% [markdown]
# # RESET

# %%
influential_csv.head(20)
# Out:
#           affirming          denying
# 0            algore   skepticscience
# 1           oxfamgb  ScienceNotDogma
# 2     globalactplan       Carbongate
# 3      GreenpeaceUK        Neets2245
# 4       WWF_Climate         Co2Green
# 5        OneClimate       thegwpfcom
# 6       Ed_Miliband     CO2Coalition
# 7     CarolineLucas     Action4Life_
# 8         DECCgovuk   fredpalmercoal
# 9     the_ecologist     NoTricksZone
# 10         James_BG       FChecker76
# 11           Revkin   caleb_rossiter
# 12      ClimateDesk  FriendsofCoalWV
# 13  climateprogress      JunkScience
# 14            grist         CO2notes
# 15       TreeHugger   ClimateSkeptic
# 16    kate_sheppard        eloarefab
# 17            drvox        adapt2030
# 18       bradplumer           JWSpry
# 19      simondonner          pplonia

# %%
curr_deny = influential_csv.iloc[69]['denying']
print('Current denying user:',curr_deny)
#c.Username = curr_affirm
# Out:
# Current denying user: FriendsOScience

# %% [markdown]
# ## RESTART HERE

# %%
config = create_twint_config(
    curr_deny,None,None)

# %%
config.__dict__
# Out:
# {'Show_hashtags': True,
#  'Count': True,
#  'Stats': True,
#  'Store_csv': True,
#  'Retweets': False,
#  'Format': 'ID {id} -||- Date {date} -||- Time {time} -||- Tweet {tweet} -||- Mentions {mentions} -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags {hashtags} -||- Username {username}',
#  'Username': 'FriendsOScience',
#  'Until': None,
#  'Search': None}

# %%
if config.Search == None:
    start_index = 0
else:
    start_index = SEARCH_TERMS.index(config.Search)

# %%
start_index
# Out:
# 0

# %%
for ix in range(7,len(SEARCH_TERMS)):
    search_term = SEARCH_TERMS[ix]
    #config.Until = None
    config.Search = search_term
    config.Output = os.getcwd()+SCRAPE_DIR+'/{}_search-term={}.csv'.format(config.Username,config.Search)
    print('Getting tweets with keyword: ' + config.Search)#search_term in SEARCH_TERMS:
    #c.Search = search_term
    #c.Pandas = True
    #c.Store_object = True
    #c.Output = os.getcwd()+SCRAPE_DIR+'/{}_search-term={}.csv'.format(c.Username,c.Search)
    twint.run.Search(config)
# Out:
# Getting tweets with keyword: emission
# ID 1114526109113044992 -||- Date 2019-04-06 -||- Time 06:51:45 -||- Tweet Correct. This refers to the Shepard 800 MW combined cycle natural gas plant and what would happen if putting 5,000 MW wind on the grid in Alberta....instead of the low emission modern $1.4 billion CCGT, old coal plants are  being converted to ngas for $50 million. Reducing CO2?  pic.twitter.com/5l4XQO92Vm -||- Mentions ramspacek,clivehbest,NoelTurner194,RoyPentland,elliot0211,Barbarajdurkin,NMorris472,no2wind,happyfinko,WaltKostrzewski,ya_pheq,lassiter1550,GillesnFio,Michael46830937,bbryson1961,DCTFTW,automaticsteam,alan_poirier,ergodrake,Tangomitteckel,Ike_Kiefer,TQMKA,JWSpry,JaggerMickOZ,csfc67,TonyPrice241,KinkerMichards,ThomasM15940165,Lynn16174075,Erst_Officer,RogTallbloke,Karajavuori,GraceIrene21,fern_60,Amilure1,n0rssec,Carbongate,WayneAllanH,bluesjack42,Hojpojj,SeanFlanderhijn,Real_BWEA,Ancientengineer,yota_berlin,Lyonseed,luisbaram,RobChristie11,drwaheeduddin,FernandoLeanme,dbirch214 -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 1113611542837071872 -||- Date 2019-04-03 -||- Time 18:17:36 -||- Tweet This: "Figure ES.2. Projected annual temperature change for Canada this century under a low emission scenario (RCP2.6) and a high emission scenario (RCP8.5). Projections are based on the Coupled Model Intercomparison Project (CMIP5) multi-model ensemble." /2 -||- Mentions RobertMuir_PEng,RossMcKitrick -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 1092122260045889536 -||- Date 2019-02-03 -||- Time 10:06:52 -||- Tweet What magical non-fossil fuel related no-GHG emission energy source will we transition to? -||- Mentions KIVUNature,PolAnimalAus,CogitoErgoSumAu,dvibrationz,badmoonrising11,bravehearttexas,GillesnFio,swcrisis,EthonRaptor,terrymorse,EcoSenseNow,Captbobdad,dunvirkin,daveaurkov,boggywood,ElQuesoSabio,DWinSTL,KCTaz,GuyEric11,Canberroo,neil_ndbress,JaggerMickOZ,JamesDe34061167,1_TMF_,SetagNodnarb,3GHtweets,Alexocasocortez,BennettVarsho,Martel7Charles,Alkynesof,miked194765,NikolovScience,SConwaySmith,wiaceka,Ike_Kiefer,reneread,aussiepride1948,myearwood65,su_js1,SLBCTexas,BigDogStar,ellinjaa,angushulmemusic,kevpluck,saykojack -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 1029434313090027520 -||- Date 2018-08-14 -||- Time 11:27:20 -||- Tweet Coal is price stable+in modern plants has little impact on air quality. Car emission standards are expensive to implement +make life harder for avg ppl. North America air quality continues to improve as does longevity. Affordable, reliable energy is key.#climatechange #uspolitics -||- Mentions GChamberlainAZ,tan123,POTUS -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #climatechange,#uspolitics -||- Username FriendsOScience
# ID 1017769360335736832 -||- Date 2018-07-13 -||- Time 06:54:59 -||- Tweet Can't think of any scientist who 'opposes' climate change. Climate always changes; the current question is to what extent humans affect climate, what activity or emission,what is the risk, if any, can it be controlled or mitigated and if so, at what cost to what benefit? -||- Mentions 3GHtweets,adlrope,d_e_mol,GillesnFio,souzou_no,MichaelEMann,sueytonius,scienceartcats,drwaheeduddin,SnakeBi14457783,RogTallbloke,alan_poirier,icarus62,Mystic_Sister,Tony_Purc,AltUS_ARC,VariabilityBlog,blaubok,wattsupwiththat,ned2au,RogerAPielkeSr,wildweatherdan,yota_berlin,CaseyParksIt,JamesAbbott2013,NikolovScience,tan123,FredFoxyGuy,scotpolitik,Ike_Kiefer,JWSpry,redforged42,JanMareeSmith2,danmangrove,Skeen1a,does_science,RonCrunt,LeoHogan2018,iMarcusCicero,tyrelle123,1_TMF_,Piers_Corbyn,jamesb_bkk,SookyBlessingtn -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID
||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 934154099003740161 -||- Date 2017-11-24 -||- Time 12:17:47 -||- Tweet The largest source of income is from coal emission carbon taxes. When the coal plants go offline, so does the money. Industry cannot increase efficiency dramatically at this stage. Already did it since 2002.  http://blog.friendsofscience.org/2016/10/20/albertas-first-climate-leadership-plan-was-established-in-2002/ … Low hanging fruit has been picked. -||- Mentions trevortombe -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 892473358490542080 -||- Date 2017-08-01 -||- Time 12:53:24 -||- Tweet PROSPECTS FOR MEETING EMISSION REDUCTION GOALS: THE CASE OF QUEBEC  http://blog.friendsofscience.org/2017/06/22/prospects-for-meeting-emission-reduction-goals-the-case-of-quebec/ … -||- Mentions E_Duhaime -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 888206508768595970 -||- Date 2017-07-20 -||- Time 18:18:28 -||- Tweet PROSPECTS FOR MEETING EMISSION REDUCTION GOALS: THE CASE OF QUEBEC   http://blog.friendsofscience.org/2017/06/22/prospects-for-meeting-emission-reduction-goals-the-case-of-quebec/ … #frab #frcan #polqc -||- Mentions RadioCanadaInfo -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #frab,#frcan,#polqc -||- Username FriendsOScience
# ID 878997668155998208 -||- Date 2017-06-25 -||- Time 08:25:49 -||- Tweet .@phcouillard @DenisCoderre @LP_LaPresse PROSPECTS FOR MEETING EMISSION REDUCTION GOALS: THE CASE OF QUEBEC  https://friendsofsciencecalgary.wordpress.com/2017/06/22/prospects-for-meeting-emission-reduction-goals-the-case-of-quebec/ … #polqc -||- Mentions phcouillard,DenisCoderre,LP_LaPresse -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #polqc -||- Username FriendsOScience
# ID 878027020055302145 -||- Date 2017-06-22 -||- Time 16:08:49 -||- Tweet PROSPECTS FOR MEETING EMISSION REDUCTION GOALS:  THE CASE OF QUEBEC  https://friendsofsciencecalgary.wordpress.com/2017/06/22/prospects-for-meeting-emission-reduction-goals-the-case-of-quebec/ … -||- Mentions  -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 866323432253911041 -||- Date 2017-05-21 -||- Time 09:02:56 -||- Tweet Lake Nyos an example of massive CO2 emission killing ppl. CO2 can be destructive, but in huge quantities in contained area. -||- Mentions CitronCockatoo,LeonardCohen2,GillesnFio,icarus62,SapientHetero,GustavoRejivik,brandonrgates,3GHtweets,BigJoeBastardi,hockeyschtick1,rln_nelson,StormSignalSA,drwaheeduddin,LindsayyuleS,RichardCowley2,JWSpry,tsteele93,Toro520,_RaulRevere,FlyMotherBaby,altUSEPA,ILuvCO2,DexterRoy527,iMarcusCicero,Billybobtn,PlanB1975,RogTallbloke,KiryeNet,tan123,DissidentFairy,adoolan34,PushBackNow,VJacobergerL,FoxNews,RoseHorowitz31,POTUS,VP,BarackObama,algore,billmckibben,NOAA,NASA,NatureClimate,curryja -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 845646443935420416 -||- Date 2017-03-25 -||- Time 07:39:58 -||- Tweet .@DannyHozack @DrewBarnesMLA We'd say #climate IS affected by CO2, but human CO2 emission effect is nominal. Taxes+Paris won't help. #ableg pic.twitter.com/2AD6WM5b6N -||- Mentions DannyHozack,Drewbarnesmla -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags
||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# [+] Finished: Successfully collected 31 Tweets from @FriendsOScience.
# Getting tweets with keyword: anthropogenic
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:Tweets_known_error:Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0) [x] run.Feed
# [!] if get this error but you know for sure that more tweets exist, please open an issue and we will investigate it!
# [+] Finished: Successfully collected 0 Tweets from @FriendsOScience.
# Getting tweets with keyword: temperature
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# [+] Finished: Successfully collected 0 Tweets from @FriendsOScience.
# Getting tweets with keyword: warming
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# ID 1193540892004499456 -||- Date 2019-11-10 -||- Time 06:48:18 -||- Tweet Actually, the overwhelming trend in scientific perspective is that CO2 is a nominal element and most recent warming was due to natural factors.  pic.twitter.com/5OvSmhB17g -||- Mentions oppchg,DawnTJ90,craigthomler,farmingganja,GillesnFio,NicholasRennie2,Fiddlers__Green,RasPuti84556755,EcoSenseNow,chant_ian,PluginAlberta,NatalCicuto,TexCIS,gridfan67059,glinch72,eric84701331,ShubertEugene,erskinedaniel,dense_evi,MATTP1949,ThomasBeyer,MichaelMaus6,GreyTash,puremoneylife,AlbertStienstra,TJ_TomJ,SylviaD32911201,CattMaxx,TallPhilosopher,BerniceRinas,ttyEngland,XRLondon,DrWonko42,angry_bystander,gogetsmarthome,JWSpry,JaggerMickOZ,drwaheeduddin,Climatearticles,VoisinSt,SlagKogel,Gladfly1,TheClimateHawk,ammocrypta,Carbongate,Ceist8,kimbetech,LGcommaI,Sou_HotWhopper,pt40fathoms -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 1192845399708405760 -||- Date 2019-11-08 -||- Time 08:44:39 -||- Tweet Same to you! Recommended reading "The Great Warming"  https://www.amazon.ca/Great-Warming-Climate-Change-Civilizations/dp/159691601X …  California had 100 and 200 yr droughts in the Medieval Warm Period 950-1250 AD. Aussie history attached. Also attached how California used to burn. #cdnpoli #abpoli pic.twitter.com/Ybe9SQX382 -||- Mentions daiicol,FairQuestions -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #cdnpoli,#abpoli -||- Username FriendsOScience
# ID 1192841546829221888 -||- Date 2019-11-08 -||- Time 08:29:21 -||- Tweet FYI. Recommended reading. The Great Warming.  https://www.amazon.ca/Great-Warming-Climate-Change-Civilizations/dp/159691601X …  California suffered 100 and 200 years droughts in the Medieval Warm Period (950-1250 AD) Here's Australia's historic record. #ableg #abpoli #cdnpoli pic.twitter.com/vVajYbMMw5 -||- Mentions CampbellShelagh -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #ableg,#abpoli,#cdnpoli -||- Username FriendsOScience
# ID 1192526520125755393 -||- Date 2019-11-07 -||- Time 11:37:33 -||- Tweet New 'big global warming scare' is simply a 'con'    https://youtu.be/ps0qpv5RVWo  #TheBoltReport #cdnpoli -||- Mentions EstulinDaniel -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #TheBoltReport,#cdnpoli -||- Username FriendsOScience
# ID 1191405035411800073 -||- Date 2019-11-04 -||- Time 09:21:10 -||- Tweet Time for the IPCC global travel warning....actually no one should be going to SPAIN for #cop25 - THINK OF THE DANGER!  https://agree-to-disagree.com/global-warming-travel-warning/ …  All that warming...  pic.twitter.com/jTURqaFU6X -||- Mentions dbirch214,TuukkaSimonen,BuzzLightyearz_,LindeVes,croman39 -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #cop25 -||- Username FriendsOScience
# ID 1191065506494607360 -||- Date 2019-11-03 -||- Time 10:52:00 -||- Tweet Lots of CO2 but no warming according to the theory.  Looks like it's natural warming, according to this IPCC graph....  pic.twitter.com/ZmvLOxfmZg -||- Mentions TinusPulles,glinch72,EwonSprokler,GillesnFio,MATTP1949,DawnTJ90,fcmfcs2019,nitecrawler1867,JesseCDNMitche1,JeremyDPeel1,amlozyk,TheClimateHawk,Sou_HotWhopper,Climatearticles,craigthomler,BadgersNo,TyotoRiffle,BySpoke,StormSignalSA,redned59,MHicks60721149,Keith_Mundy,CattMaxx,Tangomitteckel,GregDeR7,ronjj66,drwaheeduddin,DeafeningSilen4,Ceist8,cindylynn_,Mark_A_Lunn,PGtwentytwo,mcochrane21,Noonesp06242884,FossilBeBare,VoisinSt,DamoPelham,JWSpry,weatherwarsinfo,Chris_Hickman,EcoSenseNow,Chatham_Lee,trippfunderburk,UreyZen,realPitBullDog,RLChauv,Carbongate,FleischmanSteve,surfnvb21,GretaThunberg -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 1191022217967964161 -||- Date 2019-11-03 -||- Time 07:59:59 -||- Tweet A) 2 deg C target arbitrarily set by an economist who did not know that CO2 concentration is a CONSEQUENCE of warming, nominally a cause B) so the target has become POLITICAL, not scientific C) the estimates are by the economist whose target you accept.  https://www.econlib.org/library/Columns/y2018/MurphyNordhaus.html … -||- Mentions TinusPulles,EwonSprokler,glinch72,GillesnFio,MATTP1949,DawnTJ90,fcmfcs2019,nitecrawler1867,JesseCDNMitche1,JeremyDPeel1,amlozyk,TheClimateHawk,Sou_HotWhopper,Climatearticles,craigthomler,BadgersNo,TyotoRiffle,BySpoke,StormSignalSA,redned59,MHicks60721149,Keith_Mundy,CattMaxx,T
||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #carbon -||- Username FriendsOScience
# ID 1186060957467865088 -||- Date 2019-10-20 -||- Time 16:25:42 -||- Tweet .@JustinTrudeau @AndrewScheer @MaximeBernier @ElizabethMay @theJagmeetSingh @yfblanchet No #ClimateEmergency - not every place can be warming twice as fast ass the world. Come on!!  https://youtu.be/lxVoZDGluLs  #cdnpoli #elxn43 -||- Mentions JustinTrudeau,AndrewScheer,MaximeBernier,ElizabethMay,theJagmeetSingh,yfblanchet -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #ClimateEmergency,#cdnpoli,#elxn43 -||- Username FriendsOScience
# ID 1185925197959811072 -||- Date 2019-10-20 -||- Time 07:26:15 -||- Tweet .@JustinTrudeau @cathmckenna @AndrewScheer @MaximeBernier @ElizabethMay @theJagmeetSingh @yfblanchet The Roots of Global Warming... street theatre and then some.  https://youtu.be/U14NF_f0P7g  #cdnpoli #elxn43 #ClimateChangeIsReal pic.twitter.com/AhVcuK8QX3 -||- Mentions JustinTrudeau,cathmckenna,AndrewScheer,MaximeBernier,ElizabethMay,theJagmeetSingh,yfblanchet -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #cdnpoli,#elxn43,#ClimateChangeIsReal -||- Username FriendsOScience
# ID 1185915310592819200 -||- Date 2019-10-20 -||- Time 06:46:57 -||- Tweet It is an important piece of #oldnews b/c ppl keep claiming that for 100 yr the 'hothouse' theory of catastrophic carbon dioxide warming has been proven and citing Arrhenius' original work; but he amended his view. They should cite that newer perspective which is not catastrophic. -||- Mentions esmecomfort,JackRHayden -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #oldnews -||- Username FriendsOScience
# ID 1185783036152954881 -||- Date 2019-10-19 -||- Time 22:01:21 -||- Tweet .@JustinTrudeau @cathmckenna @AndrewScheer @MaximeBernier @ElizabethMay @theJagmeetSingh @yfblanchet #Carbon The Roots of Global Warming - humans are highly suggestible..  BOO!!  https://youtu.be/U14NF_f0P7g  @ElectionsCan_E #cdnpoli #elxn43 #ClimateEmergency pic.twitter.com/4TPkeAvlZc -||- Mentions JustinTrudeau,cathmckenna,AndrewScheer,MaximeBernier,ElizabethMay,theJagmeetSingh,yfblanchet,ElectionsCan_E -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #Carbon,#cdnpoli,#elxn43,#ClimateEmergency -||- Username FriendsOScience
# ID 1185255371780378624 -||- Date 2019-10-18 -||- Time 11:04:36 -||- Tweet #FunFactsFriday #DidYouKnow ?  Svante Arrhenius (who was related to Greta & developed the 'hothouse theory') amended his view in 1906 and decided that warming would top out about 1.5 degrees C and that warming would be beneficial!  Read about it here:  http://ow.ly/mm1p50wOOKp  pic.twitter.com/eOlJQydXBm -||- Mentions  -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #FunFactsFriday,#DidYouKnow -||- Username FriendsOScience
# ID 1185154354053029890 -||- Date 2019-10-18 -||- Time 04:23:11 -||- Tweet Yes, let's look at the roots of global warming, shall we?  https://youtu.be/U14NF_f0P7g  -||- Mentions ShaneRedflag,can_climate_guy -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 1185006122693849088 -||- Date 2019-10-17 -||- Time 18:34:10 -||- Tweet They're hot.😆The @EdmontonOilers will simply have to change their name now that Mayor @doniveson has declared a #ClimateEmergency - right @GretaThunberg ? @NHL Fortunately the @NHLFlames are global warming ready @nenshi. #Yeg #yyc PS NO Climate Emerg...  https://youtu.be/GpVBH-HY5Ow  pic.twitter.com/e2E7WxFDzI -||- Mentions dale8yyc,GretaThunberg,CJEdmonton,EdmontonOilers,doniveson,NHL,GlobalEdmonton,ctvedmonton,edmontonjournal,Edmontonsun,CBCEdmonton,NHLFlames,nenshi -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #ClimateEmergency,#Yeg,#yyc -||- Username FriendsOScience
# ID 1184621590215966720 -||- Date 2019-10-16 -||- Time 17:06:10 -||- Tweet Do people know how the global warming scare also began with street theatre? Seems to be a running theme...  https://youtu.be/U14NF_f0P7g  pic.twitter.com/RusEIIbIoU -||- Mentions jkenney,BigRedyyc,codyincalgary -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 1183146076561235968 -||- Date 2019-10-12 -||- Time 15:23:01 -||- Tweet Extinction Rebellion Is A Menace To Reason & Progress - The Global Warming Policy Forum (GWPF)  https://www.thegwpf.com/extinction-rebellion-is-a-menace-to-reason-progress/ … -||- Mentions  -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 1182462083637497856 -||- Date 2019-10-10 -||- Time 18:05:04 -||- Tweet The Roots of #Global Warming. Street theatre. Yeah. Really.  https://youtu.be/U14NF_f0P7g  #CanadaDebates2019 #debatdeschefs #cdnpoli #elexn43 -||- Mentions CTVNews,JustinTrudeau,AndrewScheer,theJagmeetSingh,ElizabethMay,yfblanchet,MaximeBernier -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #Global,#CanadaDebates2019,#debatdeschefs,#cdnpoli,#elexn43 -||- Username FriendsOScience
# ID 1181371010227916800 -||- Date 2019-10-07 -||- Time 17:49:32 -||- Tweet .@RosieBarton @ElizabethMay  Hot models (simulations) wildly exaggerate future warming. NO #ClimateEmergency  https://friendsofscience.org/assets/documents/Acturaries_Misguided_Oct_06_2019_FINAL.pdf … #cdnpoli pic.twitter.com/XVPjDeQsfN -||- Mentions RosieBarton,ElizabethMay -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #ClimateEmergency,#cdnpoli -||- Username FriendsOScience
# ID 1181360694177828864 -||- Date 2019-10-07 -||- Time 17:08:32 -||- Tweet #Carbon The Roots of Global Warming - street theatre. Really.    https://youtu.be/U14NF_f0P7g  We're all being had. By these guys and their ENGOs.  https://web.northeastern.edu/matthewnisbet/wp-content/uploads/2018/05/Nisbet2018_ClimatePhilanthropy_WIREsClimateChange_Final.pdf … #cdnpoli -||- Mentions CTVNews -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #Carbon,#cdnpoli -||- Username FriendsOScience
# ID 1181342750265892865 -||- Date 2019-10-07 -||- Time 15:57:14 -||- Tweet Here's how the #climate model (simulations) project future warming.  Note how far off they are from reality. Public policy is being set on computer generation 'heat' and hysteria.  pic.twitter.com/8kEk3TxPRM -||- Mentions elliot_salty,GlobalEdmonton,protectwintersc -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #climate -||- Username FriendsOScience
# ID 1181285126178623489 -||- Date 2019-10-07 -||- Time 12:08:15 -||- Tweet Yes, 4 those who may also be unfamiliar (but don't hypocritically pontificate about #climate - this graph shows the five major data sets, along with the squiggly blue line at the cop (CO2 concentration). See the flatline. Global warming hiatus. Since before Kyoto. We've been had.  pic.twitter.com/rfjNqiGWQG -||- Mentions hughjarse5,can_climate_guy,AlxTurcotte,GlobalEdmonton,UAlberta -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags
||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #Carbon,#climatechange,#cdnpoli,#Elexn43 -||- Username FriendsOScience
# ID 1179058030710640640 -||- Date 2019-10-01 -||- Time 08:38:35 -||- Tweet Let's look at the roots of global warming, shall we?  https://youtu.be/U14NF_f0P7g   Street theater a big part of it! #ableg #abpoli #cdnpoli #Elexn43 #ClimateEmergency pic.twitter.com/61xBp7phJf -||- Mentions jkenney -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #ableg,#abpoli,#cdnpoli,#Elexn43,#ClimateEmergency -||- Username FriendsOScience
# ID 1178871441724297216 -||- Date 2019-09-30 -||- Time 20:17:08 -||- Tweet The linked article here ran as a paid ad in the @edmontonjournal - but the #climate mob tore it down. It cites Dr. Richard Tol's assessment of how warming HELPS Canada's economy + growth.  https://blog.friendsofscience.org/2019/03/27/climate-science-and-economics/ … #ableg #abpoli #cdnpoli @UAlberta -||- Mentions MannockDavid,sjc_pbs,edmontonjournal,UAlberta -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #climate,#ableg,#abpoli,#cdnpoli -||- Username FriendsOScience
# ID 1178731545344933888 -||- Date 2019-09-30 -||- Time 11:01:14 -||- Tweet Thank you!Still a very large separation of CO2 and warming does not seem to be taking off... -||- Mentions NJSnowFan,KiryeNet,KitemanArgues,mentalmal1,TyotoRiffle,ttyEngland,JWSpry,tan123,SaltwaterFix,ClimatismBlog,drwaheeduddin,SinclaireTony,zwitschermaus2,Carbongate,DamoPelham,JaggerMickOZ,LpdlcRamirez,peikko763,GillesnFio,SierraClub -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 1178697904208236550 -||- Date 2019-09-30 -||- Time 08:47:34 -||- Tweet If CO2 warming was really a thing, we would see things hotter in the top end here in Canadaa, not the bottom.  pic.twitter.com/AQ2ei3kMDz -||- Mentions StephenLeahy,matthew25496877,EcoSenseNow -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 1178693975059746816 -||- Date 2019-09-30 -||- Time 08:31:57 -||- Tweet Over 150 years ago scientists had a theory that CO2 traps heat from the sun. Geologic evidence shows no correlation b/t CO2 concentration and temperature. Nature emits vast quantities of CO2, esp from oceans+land when warming. Ppl emit it, too. So?  pic.twitter.com/HLY9q7ImhD -||- Mentions StephenLeahy,matthew25496877,EcoSenseNow -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 1178693448083202048 -||- Date 2019-09-30 -||- Time 08:29:51 -||- Tweet What's wrong w your explanation? 1) The moon has no oceans. The earth has oceans; 71% of the surface is water. Water vapour is the wild card in global warming  https://www.sciencedaily.com/releases/2010/01/100131145840.htm … /2 -||- Mentions StephenLeahy,matthew25496877,EcoSenseNow -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ...
# ID 1171790691078262785 -||- Date 2019-09-11 -||- Time 07:20:46 -||- Tweet It is one element in the kit of #climate solutions - also helps recovery sweet oil from depleted wells. Extremely complex engineering challenge. You mock what you don't even understand. -||- Mentions frackfreenb,CBCCalgary,happyfinko -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags
||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #cdnpoli -||- Username FriendsOScience
# ID 1171166588122193920 -||- Date 2019-09-09 -||- Time 14:00:48 -||- Tweet Your #climate policies make housing unaffordable  https://blog.friendsofscience.org/2019/09/08/forget-the-dream-house-how-net-zero-building-codes-may-place-house-ownership-beyond-reach/ …  Or didn't you know that? #Math pic.twitter.com/ZnJPrQr1hG -||- Mentions Bill_Morneau -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #climate,#Math -||- Username FriendsOScience
# ID 1171102540961726464 -||- Date 2019-09-09 -||- Time 09:46:18 -||- Tweet Unknown. She can tell us all about #climate the world's most COMPLEX science and parrot the @ClimatePsych 's words "Our House is on Fire" but when it comes to nuclear 'I'm just a kid'. Poor her. Far too big a burden for a young person. pic.twitter.com/c6AxyY2UxY -||- Mentions Gordie_Orwell,ElectionsCan_E,CanRevAgency,DavidSuzukiFDN,ClimatePsych -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #climate -||- Username FriendsOScience
# ID 1171091833956392960 -||- Date 2019-09-09 -||- Time 09:03:45 -||- Tweet @RogerAPielkeSr has done a great deal of excellent work on how humans affect regional climate w land use, water diversion, deforestation. This is real science, not the wacky 'only 12 yr left' junk. -||- Mentions ParryGilbert,RogerAPielkeSr -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags  -||- Username FriendsOScience
# ID 1170952529141592066 -||- Date 2019-09-08 -||- Time 23:50:12 -||- Tweet Yes. But these are the words of the @climatePsych who is trying to sell her book "Climate Truth"....she is NOT a #climate scientist!!  pic.twitter.com/zAJrOfG1oY -||- Mentions RebelNewsOnline,ClimatePsych -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #climate -||- Username FriendsOScience
# ID 1170946784077594624 -||- Date 2019-09-08 -||- Time 23:27:23 -||- Tweet #TarSandsCampaign hits all of Canada Dr. Patrick Moore – Green Trade War and Climate Emergency Empty Virtue Signalling     https://youtu.be/Xa5dufs2sg4  @jkenney @sonyasavage #ableg #abpoli #skpoli #onpoli #cdnpoli -||- Mentions MaximeBernier,scrowder,EcoSenseNow,jkenney,sonyasavage -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #TarSandsCampaign,#ableg,#abpoli,#skpoli,#onpoli,#cdnpoli -||- Username FriendsOScience
# ID 1170946265527357442 -||- Date 2019-09-08 -||- Time 23:25:19 -||- Tweet All these #climate catastrophes are so invisible and remote!  Dr. Patrick Moore – Old Dying Baobab Trees   https://youtu.be/KSGUWRgv2Y4  #ClimateChangeIsReal #cdnpoli #polcan -||- Mentions MaximeBernier,scrowder,EcoSenseNow -||-     Repliescount {replies_count}     -||- Retweetscount {retweets_count} -||- Likescount {likes_count} -||- Hashtags #climate,#ClimateChangeIsReal,#cdnpoli,#polcan -||- Username FriendsOScience
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/twint/get.py in Response(session, url, params)
#     152         async with session.get(url, ssl=True, params=params, proxy=httpproxy) as response:
# --> 153             return await response.text()
#     154
#
# /anaconda3/lib/python3.7/site-packages/aiohttp/client_reqrep.py in text(self, encoding, errors)
#    1008         if self._body is None:
# -> 1009             await self.read()
#    1010
#
# /anaconda3/lib/python3.7/site-packages/aiohttp/client_reqrep.py in read(self)
#     972             try:
# --> 973                 self._body = await self.content.read()
#     974                 for trace in self._traces:
#
# /anaconda3/lib/python3.7/site-packages/aiohttp/streams.py in read(self, n)
#     357             while True:
# --> 358                 block = await self.readany()
#     359                 if not block:
#
# /anaconda3/lib/python3.7/site-packages/aiohttp/streams.py in readany(self)
#     379         while not self._buffer and not self._eof:
# --> 380             await self._wait('readany')
#     381
#
# /anaconda3/lib/python3.7/site-packages/aiohttp/streams.py in _wait(self, func_name)
#     295                 with self._timer:
# --> 296                     await waiter
#     297             else:
#
# /anaconda3/lib/python3.7/asyncio/futures.py in __await__(self)
#     259             self._asyncio_future_blocking = True
# --> 260             yield self  # This tells Task to wait for completion.
#     261         if not self.done():
#
# /anaconda3/lib/python3.7/asyncio/tasks.py in __wakeup(self, future)
#     291         try:
# --> 292             future.result()
#     293         except Exception as exc:
#
# /anaconda3/lib/python3.7/asyncio/futures.py in result(self)
#     172         if self._state == _CANCELLED:
# --> 173             raise CancelledError
#     174         if self._state != _FINISHED:
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# <ipython-input-1263-f3b8cd5d37e4> in <module>
#       9     #c.Store_object = True
#      10     #c.Output = os.getcwd()+SCRAPE_DIR+'/{}_search-term={}.csv'.format(c.Username,c.Search)
# ---> 11     twint.run.Search(config)
#
# /anaconda3/lib/python3.7/site-packages/twint/run.py in Search(config, callback)
#     290     config.Profile = False
#     291     config.Profile_full = False
# --> 292     run(config, callback)
#     293     if config.Pandas_au:
#     294         storage.panda._autoget("tweet")
#
# /anaconda3/lib/python3.7/site-packages/twint/run.py in run(config, callback)
#     211 def run(config, callback=None):
#     212     logme.debug(__name__+':run')
# --> 213     get_event_loop().run_until_complete(Twint(config).main(callback))
#     214
#     215 def Favorites(config):
#
# /anaconda3/lib/python3.7/asyncio/base_events.py in run_until_complete(self, future)
#     571             raise RuntimeError('Event loop stopped before Future completed.')
#     572
# --> 573         return future.result()
#     574
#     575     def stop(self):
#
# /anaconda3/lib/python3.7/asyncio/futures.py in result(self)
#     176         self.__log_traceback = False
#     177         if self._exception is not None:
# --> 178             raise self._exception
#     179         return self._result
#     180
#
# /anaconda3/lib/python3.7/asyncio/tasks.py in __step(***failed resolving arguments***)
#     223                 result = coro.send(None)
#     224             else:
# --> 225                 result = coro.throw(exc)
#     226         except StopIteration as exc:
#     227             if self._must_cancel:
#
# /anaconda3/lib/python3.7/site-packages/twint/run.py in main(self, callback)
#     152             task.add_done_callback(callback)
#     153
# --> 154         await task
#     155
#     156     async def run(self):
#
# /anaconda3/lib/python3.7/asyncio/futures.py in __await__(self)
#     258         if not self.done():
#     259             self._asyncio_future_blocking = True
# --> 260             yield self  # This tells Task to wait for completion.
#     261         if not self.done():
#     262             raise RuntimeError("await wasn't used with future")
#
# /anaconda3/lib/python3.7/asyncio/tasks.py in __wakeup(self, future)
#     290     def __wakeup(self, future):
#     291         try:
# --> 292             future.result()
#     293         except Exception as exc:
#     294             # This may also be a cancellation.
#
# /anaconda3/lib/python3.7/asyncio/futures.py in result(self)
#     176         self.__log_traceback = False
#     177         if self._exception is not None:
# --> 178             raise self._exception
#     179         return self._result
#     180
#
# /anaconda3/lib/python3.7/asyncio/tasks.py in __step(***failed resolving arguments***)
#     223                 result = coro.send(None)
#     224             else:
# --> 225                 result = coro.throw(exc)
#     226         except StopIteration as exc:
#     227             if self._must_cancel:
#
# /anaconda3/lib/python3.7/site-packages/twint/run.py in run(self)
#     196                     elif self.config.TwitterSearch:
#     197                         logme.debug(__name__+':Twint:main:twitter-search')
# --> 198                         await self.tweets()
#     199                 else:
#     200                     logme.debug(__name__+':Twint:main:no-more-tweets')
#
# /anaconda3/lib/python3.7/site-packages/twint/run.py in tweets(self)
#     135
#     136     async def tweets(self):
# --> 137         await self.Feed()
#     138         if self.config.Location:
#     139             logme.debug(__name__+':Twint:tweets:location')
#
# /anaconda3/lib/python3.7/site-packages/twint/run.py in Feed(self)
#      55         consecutive_errors_count = 0
#      56         while True:
# ---> 57             response = await get.RequestUrl(self.config, self.init, headers=[("User-Agent", self.user_agent)])
#      58             if self.config.Debug:
#      59                 print(response, file=open("twint-last-request.log", "w", encoding="utf-8"))
#
# /anaconda3/lib/python3.7/site-packages/twint/get.py in RequestUrl(config, init, headers)
#     117         _serialQuery = _url
#     118
# --> 119     response = await Request(_url, params=params, connector=_connector, headers=headers)
#     120
#     121     if config.Debug:
#
# /anaconda3/lib/python3.7/site-packages/twint/get.py in Request(url, connector, params, headers)
#     145     logme.debug(__name__+':Request:notConnector')
#     146     async with aiohttp.ClientSession(headers=headers, connector=None) as session:
# --> 147         return await Response(session, url, params)
#     148
#     149 async def Response(session, url, params=[]):
#
# /anaconda3/lib/python3.7/site-packages/twint/get.py in Response(session, url, params)
#     151     with timeout(100):
#     152         async with session.get(url, ssl=True, params=params, proxy=httpproxy) as response:
# --> 153             return await response.text()
#     154
#     155 async def RandomUserAgent():
#
# /anaconda3/lib/python3.7/site-packages/async_timeout/__init__.py in __exit__(self, exc_type, exc_val, exc_tb)
#      43                  exc_val: BaseException,
#      44                  exc_tb: TracebackType) -> Optional[bool]:
# ---> 45         self._do_exit(exc_type)
#      46         return None
#      47
#
# /anaconda3/lib/python3.7/site-packages/async_timeout/__init__.py in _do_exit(self, exc_type)
#      90             self._cancel_handler = None
#      91             self._task = None
# ---> 92             raise asyncio.TimeoutError
#      93         if self._timeout is not None and self._cancel_handler is not None:
#      94             self._cancel_handler.cancel()
#
# TimeoutError:

# %%
old_ix = ix

ix,search_term
# Out:
# (6, 'carbon')

# %%
latest_tweets = pd.read_csv(os.getcwd()+SCRAPE_DIR+'/{}_search-term={}.csv'.format(config.Username,search_term))
latest_date = latest_tweets['date'].iloc[-1]
config = create_twint_config(curr_deny,latest_date,config.Search)

# %% [markdown]
# Organize scraped Tweets from all searchterms in df; remove duplicates.

# %%
config.Username
# Out:
# '_My2_Cents_'

# %%
user_tweets = []
for search_term in SEARCH_TERMS:
    try:
        tweets_per_search_term = pd.read_csv(os.getcwd()+SCRAPE_DIR+'/{}_search-term={}.csv'.format(config.Username,search_term))
        tweets_per_search_term['search_term'] = search_term
        user_tweets.append(tweets_per_search_term)
    except FileNotFoundError:
        pass

# %%
len(user_tweets) # each one is a df
# Out:
# 3

# %%
user_tweets[0]
# Out:
#                     id        date      time  \
# 0  1187726013058473985  2019-10-25  06:42:03
#
#                                                tweet mentions  replies_count  \
# 0  How’d you travel there? I guarantee it involve...       []              1
#
#    retweets_count  likes_count          hashtags     username search_term
# 0               0           11  ['#climatehoax']  _my2_cents_      carbon

# %%
full_tweets = pd.concat(user_tweets,ignore_index=True)
full_tweets.shape
# Out:
# (6, 11)

# %%
full_tweets['search_term'].value_counts()
# Out:
# climate        3
# environment    2
# carbon         1
# Name: search_term, dtype: int64

# %%
#from collections import Counter
counted_ids = Counter(full_tweets['id'])
print(len([(id_,counted_ids[id_]) for id_ in counted_ids if counted_ids[id_] > 1]))
# Out:
# 0

# %%
np.sum([counted_ids[id_] for id_ in counted_ids if counted_ids[id_] > 1])
# Out:
# 0.0

# %%
full_tweets.drop_duplicates(subset ="id", keep = 'first', inplace = True)
full_tweets.shape
# Out:
# (6, 11)

# %%
print(config.Username)
# Out:
# _My2_Cents_

# %%
full_tweets.to_pickle('{}_unique_tweets.pkl'.format(config.Username))

# %%
full_tweets = pd.read_pickle('{}_unique_tweets.pkl'.format(config.Username))

# %%
full_tweets
# Out:
#                     id        date      time  \
# 0  1187726013058473985  2019-10-25  06:42:03
# 1  1176484758639063040  2019-09-24  06:13:19
# 2  1157982569419476992  2019-08-04  04:52:13
# 3  1066399215071440896  2018-11-24  10:32:40
# 4  1009141579347611650  2018-06-19  11:31:16
# 5  1009139739650347016  2018-06-19  11:23:57
#
#                                                tweet  \
# 0  How’d you travel there? I guarantee it involve...
# 1  Greta’s self-righteous fury is laughable. She,...
# 2  Just say what you mean. Government would prefe...
# 3  Assuming climate change is a problem, what do ...
# 4  And who gets to decide who really cares about ...
# 5  Under capitalism there is a direct incentive t...
#
#                                mentions  replies_count  retweets_count  \
# 0                                    []              1               0
# 1                                    []              1               2
# 2                                    []              0               1
# 3                                    []              1               0
# 4  ['capbertorelli', 'richardbspencer']              1               0
# 5  ['capbertorelli', 'richardbspencer']              1               0
#
#    likes_count            hashtags     username  search_term
# 0           11    ['#climatehoax']  _my2_cents_       carbon
# 1           14  ['#gretathumberg']  _my2_cents_      climate
# 2            3     ['#government']  _my2_cents_      climate
# 3            5                  []  _my2_cents_      climate
# 4            0                  []  _my2_cents_  environment
# 5            1                  []  _my2_cents_  environment

# %%
len(os.listdir(os.getcwd()+'/affirm_tweets/'))
# Out:
# 88

# %%
os.listdir(os.getcwd()+'/deny_tweets/')
# Out:
# ['50ShadesGreenNZ_unique_tweets.pkl',
#  'Action4Life__unique_tweets.pkl',
#  'adapt2030_unique_tweets.pkl',
#  'AmazingPatriot_unique_tweets.pkl',
#  'caleb_rossiter_unique_tweets.pkl',
#  'Carbongate_unique_tweets.pkl',
#  'ccdeditor_unique_tweets.pkl',
#  'ChrisMartzWX_unique_tweets.pkl',
#  'clim8resistance_unique_tweets.pkl',
#  'ClimateDepot_unique_tweets.pkl',
#  'ClimateRealists_unique_tweets.pkl',
#  'ClimateSkeptic_unique_tweets.pkl',
#  'ClimatismBlog_unique_tweets.pkl',
#  'co2_the_unique_tweets.pkl',
#  'CO2Coalition_unique_tweets.pkl',
#  'Co2Green_unique_tweets.pkl',
#  'CO2notes_unique_tweets.pkl',
#  'DaveMyFace_unique_tweets.pkl',
#  'dieselfastpitch_unique_tweets.pkl',
#  'EdwinThwaites_unique_tweets.pkl',
#  'Electroversenet_unique_tweets.pkl',
#  'eloarefab_unique_tweets.pkl',
#  'FChecker76_unique_tweets.pkl',
#  'fredpalmercoal_unique_tweets.pkl',
#  'FriendsofCoalWV_unique_tweets.pkl',
#  'FriendsOScience_unique_tweets.pkl',
#  'globalsugarwar_unique_tweets.pkl',
#  'grand_solar_unique_tweets.pkl',
#  'GrandSolarMin_unique_tweets.pkl',
#  'GTMGQ_unique_tweets.pkl',
#  'IceAgeBob_unique_tweets.pkl',
#  'IceAgeFarmer_unique_tweets.pkl',
#  'Ike_Kiefer_unique_tweets.pkl',
#  'IQ2high2bTexGov_unique_tweets.pkl',
#  'JimMaso02236687_unique_tweets.pkl',
#  'JunkScience_unique_tweets.pkl',
#  'JWSpry_unique_tweets.pkl',
#  'KnowYourGreen1_unique_tweets.pkl',
#  'laurienappo_unique_tweets.pkl',
#  'manny_ottawa_unique_tweets.pkl',
#  'msroberts0619_unique_tweets.pkl',
#  'Neets2245_unique_tweets.pkl',
#  'notGHGs_unique_tweets.pkl',
#  'NoTricksZone_unique_tweets.pkl',
#  'pplonia_unique_tweets.pkl',
#  'realDonaldTrump_unique_tweets.pkl',
#  'RokoshME_unique_tweets.pkl',
#  'ScienceNotDogma_unique_tweets.pkl',
#  'ScubaHobbs_unique_tweets.pkl',
#  'seanhannity_unique_tweets.pkl',
#  'skepticscience_unique_tweets.pkl',
#  'SolarPowerEng_unique_tweets.pkl',
#  'StarryPole_unique_tweets.pkl',
#  'SylviaD32911201_unique_tweets.pkl',
#  'Th3Hum4nB3ing_unique_tweets.pkl',
#  'thegwpfcom_unique_tweets.pkl',
#  'ThiagoMaia2503_unique_tweets.pkl',
#  'Timbooooon_unique_tweets.pkl',
#  'Tony__Heller_unique_tweets.pkl',
#  'uk_ecology_unique_tweets.pkl',
#  'UvMeter_unique_tweets.pkl',
#  'VFigment_unique_tweets.pkl',
#  'wattsupwiththat_unique_tweets.pkl']

# %%
all_deny_tweets = []
for file in os.listdir(os.getcwd()+'/deny_tweets/'):
    tweets_per_user = pd.read_pickle(os.getcwd()+'/deny_tweets/'+file)
    all_deny_tweets.append(tweets_per_user)

# %%
deny_tweets = pd.concat(all_deny_tweets)
deny_tweets.shape
# Out:
# (209236, 11)

# %%
# all_affirm_tweets = []
# for file in os.listdir(os.getcwd()+'/affirm_tweets/'):
#     tweets_per_user = pd.read_pickle(os.getcwd()+'/affirm_tweets/'+file)
#     all_affirm_tweets.append(tweets_per_user)

# %%
affirm_tweets = pd.concat(all_affirm_tweets)
affirm_tweets.shape
# Out:
# (230802, 11)
